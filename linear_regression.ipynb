# %% [markdown]
# <a href="https://colab.research.google.com/github/TejashreeDV/Atharvo-final-project/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([2, 4, 6, 8, 10, 12])

# %%
plt.plot(x, y)
plt.show()

# %%
w0, b = 0.1, 1.0
lr = 0.001
epochs = 1000
error= []

# %%
for epoch in range(epochs):
    epoch_cost, cost_w0, cost_b =  0,  0, 0
    for i in range(len(x)):
        y_pred = w0*x[i] + b
        epoch_cost += (y[i]-y_pred)**2

        for j in range(len(x)):
            partial_wrt_b = -2*(y[j]-(w0*x[j] + b))
            partial_wrt_w0 = (-2*x[j])*(y[j]-(w0*x[j] + b))

            cost_w0 += partial_wrt_w0
            cost_b += partial_wrt_b

        w0 = w0-lr*cost_w0
        b = b-lr*cost_b

        print("w0 = ", w0)
        print("b = ", b)
    error.append(epoch_cost)
# Out:
# w0 =  0.40380000000000005
# b =  1.0678
# w0 =  0.9532608000000001
# b =  1.1898268
# w0 =  1.6432554088
# b =  1.3415387248000001
# w0 =  2.3418329067568
# b =  1.4921354577328
# w0 =  2.915527126459085
# b =  1.610469583089021
# w0 =  3.2549556866560776
# b =  1.671025934136892
# w0 =  2.956370662450922
# b =  1.598265484087694
# w0 =  2.416599027348015
# b =  1.466158280406505
# w0 =  1.7394277214906966
# b =  1.2989600182118213
# w0 =  1.0551242495571749
# b =  1.1271182714959864
# w0 =  0.49544919680141575
# b =  0.9814358870407984
# w0 =  0.1683820829720855
# b =  0.8871674056754614
# w0 =  0.4644755128327966
# b =  0.9534493493225282
# w0 =  0.9999895266863925
# b =  1.0727819292387473
# w0 =  1.6724486056550376
# b =  1.221241565883273
# w0 =  2.3532298926273683
# b =  1.3688034622996876
# w0 =  2.912233593724931
# b =  1.4851040616781566
# w0 =  3.242836410174074
# b =  1.5452696013800407
# w0 =  2.9517388602644306
# b =  1.474527236936169
# w0 =  2.4254946938353417
# ...

# %%
w0
# Out:
# 1.9999955117756099

# %%
b
# Out:
# -1.0483569937867333e-06

# %%
y_hat = []
for xi in x:
    y_hat.append(w0*xi+b)

# %%
y_hat
# Out:
# [1.999994463418616,
#  3.999989975194226,
#  5.999985486969836,
#  7.999980998745445,
#  9.999976510521055,
#  11.999972022296665]

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
plt.scatter(x, y)
plt.plot(x, y_hat, c= "r")
plt.show()

# %%
plt.plot(range(200), error[:200])
plt.show()
