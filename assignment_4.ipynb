# %% [markdown]
# <a href="https://colab.research.google.com/github/TejashreeDV/Atharvo-final-project/blob/main/assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Errors and Exceptions Homework

# %% [markdown]
# ### Problem 1
# Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks.

# %%
for i in ['a','b','c']:
    try:
        print(i**2)
    except:
        print("ENTER A NUMBER")
# Out:
# ENTER A NUMBER
# ENTER A NUMBER
# ENTER A NUMBER

# %% [markdown]
# ### Problem 2
# Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks. Then use a <code>finally</code> block to print 'All Done.'

# %%
x = 5
y = 0
try:
    z=x/y
except:
    print("Its an ZERO ERROR")
# Out:
# Its an ZERO ERROR

# %% [markdown]
# ### Problem 3
# Write a function that asks for an integer and prints the square of it. Use a <code>while</code> loop with a <code>try</code>, <code>except</code>, <code>else</code> block to account for incorrect inputs.

# %%
def ask():
        while True:
            try:
                val = int(input("Enter a number :"))
            except:
                print("Enter a proper number")
            else:
                print("The square of the entered numer is :", val**2)
    #pass

# %%
ask()
# Out:
# Input an integer: null
# An error occurred! Please try again!
# Input an integer: 2
# Thank you, your number squared is:  4

# %% [markdown]
# # Great Job!
